# %% [markdown]
# # Using Folium to visualize unoccupied parking spots
# Folium uses the power of [leaflet.js](https://leafletjs.com/) to allow easy visualization of map data.
# - [Folium quickstart](https://python-visualization.github.io/folium/quickstart.html)
# - [API reference](https://python-visualization.github.io/folium/modules.html#module-folium.folium)

# %% [markdown]
# First, let's grab our data from the database and filter out records describing vacant parking spots.

# %%
from pymongo import MongoClient
host_ip = "192.168.1.87"

client = MongoClient(host_ip, 27017)
db = client.fit3182_db
week11 = db.week11
# Preparing the data for plotting
unoccupiedList = []

# Looping through all the data
for row in week11.find():
    # Checking if the parking spot is available
    if row['status'] == 'Unoccupied':
        # Adding the latitude and longitude to the list of unoccupied spots
        unoccupiedList.append( (float(row['latitude']), float(row['longitude'])) )

# %%
import folium

# %% [markdown]
# Initialize a map at Melbourne.

# %%
fomap = folium.Map(location=[-37.812015244225677, 144.951471202974], zoom_start=15)

# %% [markdown]
# Plot a marker for each vacant parking spot.

# %%
for loc in unoccupiedList:
    folium.Marker(location=loc, popup=f"lat={loc[0]:.2f}, lon={loc[1]:.2f}").add_to(fomap)

# %% [markdown]
# Show the map.

# %%
fomap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2cffbc9f9bac9976bfe82006c290cdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2cffbc9f9bac9976bfe82006c290cdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2cffbc9f9bac9976bfe82006c290cdc = L.map(
#                 &quot;map_f2cffbc9f9bac9976bfe82006c290cdc&quot;,
#                 {
#                     center: [-37.81201524422568, 144.951471202974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31f9df848f53aaca9b22db0f4939baa1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2cffbc9f9bac9976bfe82006c290cdc);
#
#
#             var marker_7965863b89dd89108579f74e47444d17 = L.marker(
#                 [-37.81998720271917, 144.94722109036064],
#                 {}
#             ).addTo(map_f2cffbc9f9bac9976bfe82006c290cdc);
#
#
#         var popup_56de79cfc37468d80ba07f21cea9efb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9a5bf638c0f4f20723a91ded6f46d4c = $(`&lt;div id=&quot;html_d9a5bf638c0f4f20723a91ded6f46d4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.82, lon=144.95&lt;/div&gt;`)[0];
#                 popup_56de79cfc37468d80ba07f21cea9efb9.setContent(html_d9a5bf638c0f4f20723a91ded6f46d4c);
#
#
#
#         marker_7965863b89dd89108579f74e47444d17.bindPopup(popup_56de79cfc37468d80ba07f21cea9efb9)
#         ;
#
#
#
#
#             var marker_69121c72b6f82b0ce5ebc832c2c62cd4 = L.marker(
#                 [-37.82022609875878, 144.94732041459912],
#                 {}
#             ).addTo(map_f2cffbc9f9bac9976bfe82006c290cdc);
#
#
#         var popup_ff28ac42b051469e2235bd26770b48c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfbf12406136e57a97a6a3832929f21a = $(`&lt;div id=&quot;html_dfbf12406136e57a97a6a3832929f21a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.82, lon=144.95&lt;/div&gt;`)[0];
#                 popup_ff28ac42b051469e2235bd26770b48c7.setContent(html_dfbf12406136e57a97a6a3832929f21a);
#
#
#
#         marker_69121c72b6f82b0ce5ebc832c2c62cd4.bindPopup(popup_ff28ac42b051469e2235bd26770b48c7)
#         ;
#
#
#
#
#             var marker_3c7ef9bb480a444ef727793c789a4c80 = L.marker(
#                 [-37.82028436997928, 144.94539316862245],
#                 {}
#             ).addTo(map_f2cffbc9f9bac9976bfe82006c290cdc);
#
#
#         var popup_560da8c94e2c68f447b357349ef41d86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87a4be8ed13a20db270551d38eed3976 = $(`&lt;div id=&quot;html_87a4be8ed13a20db270551d38eed3976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.82, lon=144.95&lt;/div&gt;`)[0];
#                 popup_560da8c94e2c68f447b357349ef41d86.setContent(html_87a4be8ed13a20db270551d38eed3976);
#
#
#
#         marker_3c7ef9bb480a444ef727793c789a4c80.bindPopup(popup_560da8c94e2c68f447b357349ef41d86)
#         ;
#
#
#
#
#             var marker_7c47e3988f32a31d945a9b9f5bbd9729 = L.marker(
#                 [-37.820228350801294, 144.94537956681978],
#                 {}
#             ).addTo(map_f2cffbc9f9bac9976bfe82006c290cdc);
#
#
#         var popup_82fe0be8a518dc0f43e56521b09cc936 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a92affde95cbfbadd0d5d1af473686fd = $(`&lt;div id=&quot;html_a92affde95cbfbadd0d5d1af473686fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.82, lon=144.95&lt;/div&gt;`)[0];
#                 popup_82fe0be8a518dc0f43e56521b09cc936.setContent(html_a92affde95cbfbadd0d5d1af473686fd);
#
#
#
#         marker_7c47e3988f32a31d945a9b9f5bbd9729.bindPopup(popup_82fe0be8a518dc0f43e56521b09cc936)
#         ;
#
#
#
#
#             var marker_496b7ead52801cd50ebfa2d8dad7f609 = L.marker(
#                 [-37.82034602968902, 144.94540985617547],
#                 {}
#             ).addTo(map_f2cffbc9f9bac9976bfe82006c290cdc);
#
#
#         var popup_c9e6fa9971c50863f4601e6730a81ed6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1dea41c307ac51b7a98f3d77209e1a3c = $(`&lt;div id=&quot;html_1dea41c307ac51b7a98f3d77209e1a3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.82, lon=144.95&lt;/div&gt;`)[0];
#                 popup_c9e6fa9971c50863f4601e6730a81ed6.setContent(html_1dea41c307ac51b7a98f3d77209e1a3c);
#
#
#
#         marker_496b7ead52801cd50ebfa2d8dad7f609.bindPopup(popup_c9e6fa9971c50863f4601e6730a81ed6)

# %% [markdown]
# If you want, you can save the map to a file for later viewing.

# %%
fomap.save('parking-spots.html')
